# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("PEA11.20231025T121029.csv")

# %%
data.head()
# Out:
#                   STATISTIC Label  Year Single Year of Age         Sex  \
# 0  Population estimates from 1926  1926           All ages  Both sexes
# 1  Population estimates from 1926  1926           All ages        Male
# 2  Population estimates from 1926  1926           All ages      Female
# 3  Population estimates from 1926  1926       Under 1 year  Both sexes
# 4  Population estimates from 1926  1926       Under 1 year        Male
#
#      UNIT    VALUE
# 0  Number  2971992
# 1  Number  1506889
# 2  Number  1465103
# 3  Number    55391
# 4  Number    28084

# %%
data.tail
# Out:
# <bound method NDFrame.tail of                       STATISTIC Label  Year Single Year of Age         Sex  \
# 0      Population estimates from 1926  1926           All ages  Both sexes
# 1      Population estimates from 1926  1926           All ages        Male
# 2      Population estimates from 1926  1926           All ages      Female
# 3      Population estimates from 1926  1926       Under 1 year  Both sexes
# 4      Population estimates from 1926  1926       Under 1 year        Male
# ...                               ...   ...                ...         ...
# 11812  Population estimates from 1926  2023           98 years        Male
# 11813  Population estimates from 1926  2023           98 years      Female
# 11814  Population estimates from 1926  2023  99 years and over  Both sexes
# 11815  Population estimates from 1926  2023  99 years and over        Male
# 11816  Population estimates from 1926  2023  99 years and over      Female
#
#          UNIT    VALUE
# 0      Number  2971992
# 1      Number  1506889
# 2      Number  1465103
# 3      Number    55391
# 4      Number    28084
# ...       ...      ...
# 11812  Number      197
# 11813  Number      632
# 11814  Number     1600
# 11815  Number      352
# 11816  Number     1248
#
# [11817 rows x 6 columns]>

# %%
data.info
# Out:
# <bound method DataFrame.info of                       STATISTIC Label  Year Single Year of Age         Sex  \
# 0      Population estimates from 1926  1926           All ages  Both sexes
# 1      Population estimates from 1926  1926           All ages        Male
# 2      Population estimates from 1926  1926           All ages      Female
# 3      Population estimates from 1926  1926       Under 1 year  Both sexes
# 4      Population estimates from 1926  1926       Under 1 year        Male
# ...                               ...   ...                ...         ...
# 11812  Population estimates from 1926  2023           98 years        Male
# 11813  Population estimates from 1926  2023           98 years      Female
# 11814  Population estimates from 1926  2023  99 years and over  Both sexes
# 11815  Population estimates from 1926  2023  99 years and over        Male
# 11816  Population estimates from 1926  2023  99 years and over      Female
#
#          UNIT    VALUE
# 0      Number  2971992
# 1      Number  1506889
# 2      Number  1465103
# 3      Number    55391
# 4      Number    28084
# ...       ...      ...
# 11812  Number      197
# 11813  Number      632
# 11814  Number     1600
# 11815  Number      352
# 11816  Number     1248
#
# [11817 rows x 6 columns]>

# %%
data.shape
# Out:
# (11817, 6)

# %%
data.describe()
# Out:
#                Year         VALUE
# count  11817.000000  1.181700e+04
# mean    1996.410256  5.352461e+04
# std       24.463165  2.867754e+05
# min     1926.000000  6.000000e+00
# 25%     1986.000000  1.242700e+04
# 50%     2004.000000  2.667500e+04
# 75%     2014.000000  3.557700e+04
# max     2023.000000  5.281612e+06

# %%
data.isnull().sum()
# Out:
# STATISTIC Label       0
# Year                  0
# Single Year of Age    0
# Sex                   0
# UNIT                  0
# VALUE                 0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11817 entries, 0 to 11816
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   STATISTIC Label     11817 non-null  object
#  1   Year                11817 non-null  int64
#  2   Single Year of Age  11817 non-null  object
#  3   Sex                 11817 non-null  object
#  4   UNIT                11817 non-null  object
#  5   VALUE               11817 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 554.0+ KB

# %%
data["Single Year of Age"].unique()
# Out:
# array(['All ages', 'Under 1 year', '1 year', '2 years', '3 years',
#        '4 years', '5 years', '6 years', '7 years', '8 years', '9 years',
#        '10 years', '11 years', '12 years', '13 years', '14 years',
#        '15 years', '16 years', '17 years', '18 years', '19 years',
#        '20 years', '21 years', '22 years', '23 years', '24 years',
#        '25 years', '26 years', '27 years', '28 years', '29 years',
#        '30 years', '31 years', '32 years', '33 years', '34 years',
#        '35 years', '36 years', '37 years', '38 years', '39 years',
#        '40 years', '41 years', '42 years', '43 years', '44 years',
#        '45 years', '46 years', '47 years', '48 years', '49 years',
#        '50 years', '51 years', '52 years', '53 years', '54 years',
#        '55 years', '56 years', '57 years', '58 years', '59 years',
#        '60 years', '61 years', '62 years', '63 years', '64 years',
#        '65 years', '66 years', '67 years', '68 years', '69 years',
#        '70 years', '71 years', '72 years', '73 years', '74 years',
#        '75 years', '76 years', '77 years', '78 years', '79 years',
#        '80 years', '81 years', '82 years', '83 years', '84 years',
#        '85 years', '86 years', '87 years', '88 years', '89 years',
#        '90 years', '91 years', '92 years', '93 years', '94 years',
#        '95 years', '96 years', '97 years', '98 years',
#        '99 years and over'], dtype=object)

# %%
values_to_remove =["All ages"]
data = data[~data["Single Year of Age"].isin(values_to_remove)]

# %%
##也可以用Drop来实现，但是实现的过程更复杂一些
##values_to_remove =["All ages"]
##indices_to_remove = df[df["Single Year of Age"].isin(values_to_remove)].index
##df =df.drop(indices_to_remove)

# %%
#ages = data["Single Year of Age"].unique()

#for i in ages:
    #if i[:1] == "U":
        #data.loc[data["Single Year of Age"] =="Under 1 year","Single Year of Age"] = 0.5
        #data["Single Year of Age"].replace("U",0.5,inplace = True)
    #else:
        #data.loc[data["Single Year of Age"] == i,"Single Year of Age"] = int(i[:2])
        #data["Single Year of Age"].replace(i,int(i[:2]),inplace = True)


#C:\Users\luozh\anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py:1763: SettingWithCopyWarning:         
#A value is trying to be set on a copy of a slice from a DataFrame.
#Try using .loc[row_indexer,col_indexer] = value instead
#See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#isetter(loc, value)

# %%
class AgeDataProcessor:
    def __init__(self,data):
        self.data = data
        self.ages = data["Single Year of Age"].unique()
    
    def process_ages(self):
        for i in self.ages:
            if i[:1] == "U":
                self.data.loc[self.data["Single Year of Age"] =="Under 1 year","Single Year of Age"] = 0.5
            else:
                self.data.loc[self.data["Single Year of Age"] == i,"Single Year of Age"] = float(i[:2])
processor = AgeDataProcessor(data)
processor.process_ages()
print(data)
# Out:
#                       STATISTIC Label  Year Single Year of Age         Sex  \
# 3      Population estimates from 1926  1926                0.5  Both sexes
# 4      Population estimates from 1926  1926                0.5        Male
# 5      Population estimates from 1926  1926                0.5      Female
# 6      Population estimates from 1926  1926                1.0  Both sexes
# 7      Population estimates from 1926  1926                1.0        Male
# ...                               ...   ...                ...         ...
# 11812  Population estimates from 1926  2023               98.0        Male
# 11813  Population estimates from 1926  2023               98.0      Female
# 11814  Population estimates from 1926  2023               99.0  Both sexes
# 11815  Population estimates from 1926  2023               99.0        Male
# 11816  Population estimates from 1926  2023               99.0      Female
#
#          UNIT  VALUE
# 3      Number  55391
# 4      Number  28084
# 5      Number  27307
# 6      Number  55876
# 7      Number  28374
# ...       ...    ...
# 11812  Number    197
# 11813  Number    632
# 11814  Number   1600
# 11815  Number    352
# 11816  Number   1248
#
# [11700 rows x 6 columns]

# %%
data["Single Year of Age"]
# Out:
# 3         0.5
# 4         0.5
# 5         0.5
# 6         1.0
# 7         1.0
#          ...
# 11812    98.0
# 11813    98.0
# 11814    99.0
# 11815    99.0
# 11816    99.0
# Name: Single Year of Age, Length: 11700, dtype: object

# %%
data
# Out:
#                       STATISTIC Label  Year Single Year of Age         Sex  \
# 3      Population estimates from 1926  1926                0.5  Both sexes
# 4      Population estimates from 1926  1926                0.5        Male
# 5      Population estimates from 1926  1926                0.5      Female
# 6      Population estimates from 1926  1926                1.0  Both sexes
# 7      Population estimates from 1926  1926                1.0        Male
# ...                               ...   ...                ...         ...
# 11812  Population estimates from 1926  2023               98.0        Male
# 11813  Population estimates from 1926  2023               98.0      Female
# 11814  Population estimates from 1926  2023               99.0  Both sexes
# 11815  Population estimates from 1926  2023               99.0        Male
# 11816  Population estimates from 1926  2023               99.0      Female
#
#          UNIT  VALUE
# 3      Number  55391
# 4      Number  28084
# 5      Number  27307
# 6      Number  55876
# 7      Number  28374
# ...       ...    ...
# 11812  Number    197
# 11813  Number    632
# 11814  Number   1600
# 11815  Number    352
# 11816  Number   1248
#
# [11700 rows x 6 columns]

# %%
data_birth = data[data["Single Year of Age"] == 0.5 ]
data_birth
# Out:
#                       STATISTIC Label  Year Single Year of Age         Sex  \
# 3      Population estimates from 1926  1926                0.5  Both sexes
# 4      Population estimates from 1926  1926                0.5        Male
# 5      Population estimates from 1926  1926                0.5      Female
# 306    Population estimates from 1926  1936                0.5  Both sexes
# 307    Population estimates from 1926  1936                0.5        Male
# ...                               ...   ...                ...         ...
# 11215  Population estimates from 1926  2022                0.5        Male
# 11216  Population estimates from 1926  2022                0.5      Female
# 11517  Population estimates from 1926  2023                0.5  Both sexes
# 11518  Population estimates from 1926  2023                0.5        Male
# 11519  Population estimates from 1926  2023                0.5      Female
#
#          UNIT  VALUE
# 3      Number  55391
# 4      Number  28084
# 5      Number  27307
# 306    Number  53606
# 307    Number  27152
# ...       ...    ...
# 11215  Number  29546
# 11216  Number  28138
# 11517  Number  55716
# 11518  Number  27418
# 11519  Number  28298
#
# [117 rows x 6 columns]

# %%
value_to_remove = 'Both sexes'

data = data[data["Sex"] != value_to_remove]

data
# Out:
#                       STATISTIC Label  Year Single Year of Age     Sex  \
# 4      Population estimates from 1926  1926                0.5    Male
# 5      Population estimates from 1926  1926                0.5  Female
# 7      Population estimates from 1926  1926                1.0    Male
# 8      Population estimates from 1926  1926                1.0  Female
# 10     Population estimates from 1926  1926                2.0    Male
# ...                               ...   ...                ...     ...
# 11810  Population estimates from 1926  2023               97.0  Female
# 11812  Population estimates from 1926  2023               98.0    Male
# 11813  Population estimates from 1926  2023               98.0  Female
# 11815  Population estimates from 1926  2023               99.0    Male
# 11816  Population estimates from 1926  2023               99.0  Female
#
#          UNIT  VALUE
# 4      Number  28084
# 5      Number  27307
# 7      Number  28374
# 8      Number  27502
# 10     Number  29728
# ...       ...    ...
# 11810  Number    821
# 11812  Number    197
# 11813  Number    632
# 11815  Number    352
# 11816  Number   1248
#
# [7800 rows x 6 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

ohot = OneHotEncoder(sparse = False)

ohot.fit_transform(data[["Sex"]])

data = pd.get_dummies(data,prefix = "Sex",columns = ["Sex"])

data
# Out:
#                       STATISTIC Label  Year Single Year of Age    UNIT  VALUE  \
# 4      Population estimates from 1926  1926                0.5  Number  28084
# 5      Population estimates from 1926  1926                0.5  Number  27307
# 7      Population estimates from 1926  1926                1.0  Number  28374
# 8      Population estimates from 1926  1926                1.0  Number  27502
# 10     Population estimates from 1926  1926                2.0  Number  29728
# ...                               ...   ...                ...     ...    ...
# 11810  Population estimates from 1926  2023               97.0  Number    821
# 11812  Population estimates from 1926  2023               98.0  Number    197
# 11813  Population estimates from 1926  2023               98.0  Number    632
# 11815  Population estimates from 1926  2023               99.0  Number    352
# 11816  Population estimates from 1926  2023               99.0  Number   1248
#
#        Sex_Female  Sex_Male
# 4               0         1
# 5               1         0
# 7               0         1
# 8               1         0
# 10              0         1
# ...           ...       ...
# 11810           1         0
# 11812           0         1
# 11813           1         0
# 11815           0         1
# 11816           1         0
#
# [7800 rows x 7 columns]

# %%
data = data.reset_index(drop=True)
data
# Out:
#                      STATISTIC Label  Year Single Year of Age    UNIT  VALUE  \
# 0     Population estimates from 1926  1926                0.5  Number  28084
# 1     Population estimates from 1926  1926                0.5  Number  27307
# 2     Population estimates from 1926  1926                1.0  Number  28374
# 3     Population estimates from 1926  1926                1.0  Number  27502
# 4     Population estimates from 1926  1926                2.0  Number  29728
# ...                              ...   ...                ...     ...    ...
# 7795  Population estimates from 1926  2023               97.0  Number    821
# 7796  Population estimates from 1926  2023               98.0  Number    197
# 7797  Population estimates from 1926  2023               98.0  Number    632
# 7798  Population estimates from 1926  2023               99.0  Number    352
# 7799  Population estimates from 1926  2023               99.0  Number   1248
#
#       Sex_Female  Sex_Male
# 0              0         1
# 1              1         0
# 2              0         1
# 3              1         0
# 4              0         1
# ...          ...       ...
# 7795           1         0
# 7796           0         1
# 7797           1         0
# 7798           0         1
# 7799           1         0
#
# [7800 rows x 7 columns]

# %%
data.drop(["STATISTIC Label","UNIT"],axis = 1,inplace = True)

# %%
data =data[["Year","Single Year of Age","Sex_Female","Sex_Male","VALUE"]]

# %%
data.head()
# Out:
#    Year Single Year of Age  Sex_Female  Sex_Male  VALUE
# 0  1926                0.5           0         1  28084
# 1  1926                0.5           1         0  27307
# 2  1926                1.0           0         1  28374
# 3  1926                1.0           1         0  27502
# 4  1926                2.0           0         1  29728

# %%
data.shape
# Out:
# (7800, 5)

# %%
data.describe()
# Out:
#               Year   Sex_Female     Sex_Male         VALUE
# count  7800.000000  7800.000000  7800.000000   7800.000000
# mean   1996.410256     0.500000     0.500000  20272.447821
# std      24.463698     0.500032     0.500032  11910.053644
# min    1926.000000     0.000000     0.000000      6.000000
# 25%    1986.000000     0.000000     0.000000  10576.750000
# 50%    2004.000000     0.500000     0.500000  22863.000000
# 75%    2014.000000     1.000000     1.000000  30243.000000
# max    2023.000000     1.000000     1.000000  44954.000000

# %%
plt.boxplot(data["VALUE"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21cacf8f3a0>,
#   <matplotlib.lines.Line2D at 0x21cacf8f670>],
#  'caps': [<matplotlib.lines.Line2D at 0x21cacf8f940>,
#   <matplotlib.lines.Line2D at 0x21cacf8fc10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21cacf8f0d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21cacf8fee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21cacfa21f0>],
#  'means': []}

# %%
data_male_birth = data_birth[data_birth["Sex"] == "Male"]

data_male_birth = data_male_birth["VALUE"].sum()
data_male_birth
# Out:
# 1232579

# %%
data_female_birth = data_birth[data_birth["Sex"] == "Female"]
data_female_birth = data_female_birth["VALUE"].sum()
data_female_birth
# Out:
# 1176220

# %%
from scipy.stats import binom_test

observed_male = data_male_birth
observed_female = data_female_birth

total_birth = observed_male + observed_female

p = 0.5

p_value_male = binom_test(observed_male, n=total_birth, p = p,alternative='two-sided') 

print("p value of Male:", p_value_male)

alpha = 0.05  

if p_value_male < alpha:
    
    print("Reject the null hypothesis: The distribution of male births differs significantly from the expected binomial distribution. ")
    
else:
    
    print("Not rejecting the null hypothesis: The distribution of male births does not differ significantly from the expected binomial distribution")
# Out:
# p value of Male: 9.69875184393043e-289
# Reject the null hypothesis: The distribution of male births differs significantly from the expected binomial distribution.
# C:\Users\luozh\anaconda3\lib\site-packages\scipy\stats\_discrete_distns.py:78: RuntimeWarning: divide by zero encountered in _binom_pdf
#   return _boost._binom_pdf(x, n, p)

# %%
data_birth
# Out:
#                       STATISTIC Label  Year Single Year of Age         Sex  \
# 3      Population estimates from 1926  1926                0.5  Both sexes
# 4      Population estimates from 1926  1926                0.5        Male
# 5      Population estimates from 1926  1926                0.5      Female
# 306    Population estimates from 1926  1936                0.5  Both sexes
# 307    Population estimates from 1926  1936                0.5        Male
# ...                               ...   ...                ...         ...
# 11215  Population estimates from 1926  2022                0.5        Male
# 11216  Population estimates from 1926  2022                0.5      Female
# 11517  Population estimates from 1926  2023                0.5  Both sexes
# 11518  Population estimates from 1926  2023                0.5        Male
# 11519  Population estimates from 1926  2023                0.5      Female
#
#          UNIT  VALUE
# 3      Number  55391
# 4      Number  28084
# 5      Number  27307
# 306    Number  53606
# 307    Number  27152
# ...       ...    ...
# 11215  Number  29546
# 11216  Number  28138
# 11517  Number  55716
# 11518  Number  27418
# 11519  Number  28298
#
# [117 rows x 6 columns]

# %%
data_male_birth = data_birth[data_birth["Sex"] == "Male"]
data_male_birth
# Out:
#                       STATISTIC Label  Year Single Year of Age   Sex    UNIT  \
# 4      Population estimates from 1926  1926                0.5  Male  Number
# 307    Population estimates from 1926  1936                0.5  Male  Number
# 610    Population estimates from 1926  1946                0.5  Male  Number
# 913    Population estimates from 1926  1951                0.5  Male  Number
# 1216   Population estimates from 1926  1961                0.5  Male  Number
# 1519   Population estimates from 1926  1966                0.5  Male  Number
# 1822   Population estimates from 1926  1971                0.5  Male  Number
# 2125   Population estimates from 1926  1979                0.5  Male  Number
# 2428   Population estimates from 1926  1981                0.5  Male  Number
# 2731   Population estimates from 1926  1986                0.5  Male  Number
# 3034   Population estimates from 1926  1991                0.5  Male  Number
# 3337   Population estimates from 1926  1996                0.5  Male  Number
# 3640   Population estimates from 1926  1997                0.5  Male  Number
# 3943   Population estimates from 1926  1998                0.5  Male  Number
# 4246   Population estimates from 1926  1999                0.5  Male  Number
# 4549   Population estimates from 1926  2000                0.5  Male  Number
# 4852   Population estimates from 1926  2001                0.5  Male  Number
# 5155   Population estimates from 1926  2002                0.5  Male  Number
# 5458   Population estimates from 1926  2003                0.5  Male  Number
# 5761   Population estimates from 1926  2004                0.5  Male  Number
# 6064   Population estimates from 1926  2005                0.5  Male  Number
# 6367   Population estimates from 1926  2006                0.5  Male  Number
# 6670   Population estimates from 1926  2007                0.5  Male  Number
# 6973   Population estimates from 1926  2008                0.5  Male  Number
# 7276   Population estimates from 1926  2009                0.5  Male  Number
# 7579   Population estimates from 1926  2010                0.5  Male  Number
# 7882   Population estimates from 1926  2011                0.5  Male  Number
# 8185   Population estimates from 1926  2012                0.5  Male  Number
# 8488   Population estimates from 1926  2013                0.5  Male  Number
# 8791   Population estimates from 1926  2014                0.5  Male  Number
# 9094   Population estimates from 1926  2015                0.5  Male  Number
# 9397   Population estimates from 1926  2016                0.5  Male  Number
# 9700   Population estimates from 1926  2017                0.5  Male  Number
# 10003  Population estimates from 1926  2018                0.5  Male  Number
# 10306  Population estimates from 1926  2019                0.5  Male  Number
# 10609  Population estimates from 1926  2020                0.5  Male  Number
# 10912  Population estimates from 1926  2021                0.5  Male  Number
# 11215  Population estimates from 1926  2022                0.5  Male  Number
# 11518  Population estimates from 1926  2023                0.5  Male  Number
#
#        VALUE
# 4      28084
# 307    27152
# 610    33798
# 913    32630
# 1216   32137
# 1519   32514
# 1822   33276
# 2125   36171
# 2428   37717
# 2731   31315
# 3034   27390
# 3337   25231
# 3640   26077
# 3943   27036
# 4246   27437
# 4549   27633
# 4852   28427
# 5155   27805
# 5458   31047
# 5761   31452
# 6064   31490
# 6367   31302
# 6670   34101
# 6973   36855
# 7276   37673
# 7579   38480
# 7882   36880
# 8185   37255
# 8488   35061
# 8791   34332
# 9094   32806
# 9397   31854
# 9700   32433
# 10003  31689
# 10306  30809
# 10609  29845
# 10912  28421
# 11215  29546
# 11518  27418

# %%
data_male_birth = data_male_birth.tail(24)
data_male_birth = data_male_birth[["Year","VALUE"]]
data_male_birth = data_male_birth.reset_index(drop=True)
data_male_birth
# Out:
#     Year  VALUE
# 0   2000  27633
# 1   2001  28427
# 2   2002  27805
# 3   2003  31047
# 4   2004  31452
# 5   2005  31490
# 6   2006  31302
# 7   2007  34101
# 8   2008  36855
# 9   2009  37673
# 10  2010  38480
# 11  2011  36880
# 12  2012  37255
# 13  2013  35061
# 14  2014  34332
# 15  2015  32806
# 16  2016  31854
# 17  2017  32433
# 18  2018  31689
# 19  2019  30809
# 20  2020  29845
# 21  2021  28421
# 22  2022  29546
# 23  2023  27418

# %%
from scipy.stats import poisson, chisquare
years = data_male_birth["Year"]
boys_count = data_male_birth["VALUE"]

mean_boys = np.mean(boys_count)

expected_counts = [mean_boys] * len(boys_count)

chi2_stat, p_val = chisquare(boys_count, expected_counts)

print(f"Chi2 Stat: {chi2_stat}")
print(f"P Value: {p_val}")

alpha = 0.05 

if p_value_male < alpha:
    
    print("Reject the null hypothesis, the data does not follow a Poisson distribution ")
    
else:
    
    print("Fail to reject the null hypothesis, the data follows a Poisson distribution.")
# Out:
# Chi2 Stat: 8204.58682647099
# P Value: 0.0
# Reject the null hypothesis, the data does not follow a Poisson distribution

# %%
import scipy.stats as stats
stats.probplot(data_male_birth["VALUE"], dist="norm", plot=plt)
plt.title("QQ Plot")
plt.show()

# %%
shapiro_test_statistic, shapiro_p_value = stats.shapiro(data_male_birth["VALUE"])
print("Shapiro-Wilk Test p-value:", shapiro_p_value)
alpha = 0.05
# Out:
# Shapiro-Wilk Test p-value: 0.15492160618305206

# %%
if shapiro_p_value < alpha:
    
    print("Reject the null hypothesis, the data does not follow a Normal distribution ")
    
else:
    
    print("Fail to reject the null hypothesis, the data follows a Normal distribution.")
# Out:
# Fail to reject the null hypothesis, the data follows a Normal distribution.

# %%
data
# Out:
#       Year Single Year of Age  Sex_Female  Sex_Male  VALUE
# 0     1926                0.5           0         1  28084
# 1     1926                0.5           1         0  27307
# 2     1926                1.0           0         1  28374
# 3     1926                1.0           1         0  27502
# 4     1926                2.0           0         1  29728
# ...    ...                ...         ...       ...    ...
# 7795  2023               97.0           1         0    821
# 7796  2023               98.0           0         1    197
# 7797  2023               98.0           1         0    632
# 7798  2023               99.0           0         1    352
# 7799  2023               99.0           1         0   1248
#
# [7800 rows x 5 columns]

# %%
age_group= data.groupby("Single Year of Age")["VALUE"].sum()

# %%
type(age_group)
# Out:
# pandas.core.series.Series

# %%
age_group_df = age_group.reset_index()

# %%
age_group_df
# Out:
#     Single Year of Age    VALUE
# 0                  0.5  2408799
# 1                  1.0  2386266
# 2                  2.0  2378626
# 3                  3.0  2386960
# 4                  4.0  2392144
# ..                 ...      ...
# 95                95.0    34382
# 96                96.0    23900
# 97                97.0    17056
# 98                98.0    11787
# 99                99.0    21034
#
# [100 rows x 2 columns]

# %%
bins = range(0, 110, 10)
labels = [f"{i}-{i+9}" for i in range(0, 100, 10)]
age_group_df['Single Year of Age'] = pd.cut(age_group_df['Single Year of Age'], bins=bins, labels=labels, right=False)

# %%
grouped_population = age_group_df.groupby('Single Year of Age')['VALUE'].sum()

# %%
grouped_population
# Out:
# Single Year of Age
# 0-9      24043414
# 10-19    23896919
# 20-29    22560465
# 30-39    23140943
# 40-49    21024520
# 50-59    17345438
# 60-69    13241821
# 70-79     8698341
# 80-89     3623717
# 90-99      549515
# Name: VALUE, dtype: int64

# %%
grouped_population =grouped_population.reset_index()

# %%
grouped_population.plot(kind='bar', figsize=(10, 6))
plt.title('Population by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Population Count')
plt.show()

# %%
row_index = data.index[data['Year'] == 1996]

# %%
row_index[0]
# Out:
# 2200

# %%
data = data[2200:]

# %%
data= data.reset_index(drop=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data['Single Year of Age'] = data['Single Year of Age'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5600 entries, 0 to 5599
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                5600 non-null   int64
#  1   Single Year of Age  5600 non-null   float64
#  2   Sex_Female          5600 non-null   uint8
#  3   Sex_Male            5600 non-null   uint8
#  4   VALUE               5600 non-null   int64
# dtypes: float64(1), int64(2), uint8(2)
# memory usage: 142.3 KB

# %%
correlation_matrix = data.corr()

# %%
correlation_matrix
# Out:
#                             Year  Single Year of Age    Sex_Female  \
# Year                1.000000e+00        1.103015e-14  7.033112e-17
# Single Year of Age  1.103015e-14        1.000000e+00  1.099216e-18
# Sex_Female          7.033112e-17        1.099216e-18  1.000000e+00
# Sex_Male            2.822591e-15        9.826988e-17 -1.000000e+00
# VALUE               2.018366e-01       -8.635254e-01  1.341896e-02
#
#                         Sex_Male     VALUE
# Year                2.822591e-15  0.201837
# Single Year of Age  9.826988e-17 -0.863525
# Sex_Female         -1.000000e+00  0.013419
# Sex_Male            1.000000e+00 -0.013419
# VALUE              -1.341896e-02  1.000000

# %%
plt.figure(figsize=(10, 8))  # 设置图的大小
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
x = data.iloc[:,0:4]

# %%
x[:3]
# Out:
#    Year  Single Year of Age  Sex_Female  Sex_Male
# 0  1996                 0.5           0         1
# 1  1996                 0.5           1         0
# 2  1996                 1.0           0         1

# %%
y = data.iloc[:,-1]

# %%
y[:3]
# Out:
# 0    25231
# 1    23623
# 2    24963
# Name: VALUE, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[-1.67125804, -1.69816984, -1.        ,  1.        ],
#        [-1.67125804, -1.69816984,  1.        , -1.        ],
#        [-1.67125804, -1.68084335, -1.        ,  1.        ],
#        ...,
#        [ 1.67125804,  1.68049682,  1.        , -1.        ],
#        [ 1.67125804,  1.71514981, -1.        ,  1.        ],
#        [ 1.67125804,  1.71514981,  1.        , -1.        ]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.model_selection import cross_val_score

# %%
(393353**0.5)/25231 *100
# Out:
# 2.485746117678032

# %%
810/25231 *100
# Out:
# 3.2103364908247793

# %%
656516.00171429  ** 0.5
# Out:
# 810.2567504898

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score, KFold

knn = KNeighborsRegressor(n_neighbors=5)
scores = cross_val_score(knn, x, y, cv=20, scoring='neg_mean_squared_error')

print(f"MSE for each fold are: {-scores}")
print(f"Average MSE: {-np.mean(scores)}")
# Out:
# MSE for each fold are: [ 656737.00442857  269975.24814286  314114.88571429  701994.89214286
#   142542.89        678462.55471429  306932.28385714  593941.781
#  1731588.05885714  273276.57214286 1140064.401       254131.78857143
#   248404.87671429  495229.48614286  292817.01442857  689915.94714286
#   492198.11142857  410326.42814286  526195.15357143  812847.66914286]
# Average MSE: 551584.8523642856

# %%
model = KNeighborsRegressor(n_neighbors=10)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("KNN regression (MSE):", mse)
print("KNN regression - R平方 (R-squared):", r2)
# Out:
# KNN regression (MSE): 389110.6528482144
# KNN regression - R平方 (R-squared): 0.99731911815562

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Multiple Linear Regression (MSE):", mse)
print("Multiple Linear Regression R平方 (R-squared):", r2)
# Out:
# Multiple Linear Regression (MSE): 30872517.96487023
# Multiple Linear Regression R平方 (R-squared): 0.7872955358675264

# %%
from sklearn.linear_model import Ridge
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)
y_pred = ridge_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Coefficients: \n', ridge_model.coef_)
print('Mean squared error: %.2f' % mse)
print('Coefficient of determination: %.2f' % r2)
# Out:
# Coefficients:
#  [  2440.52181219 -10415.1777343      70.66290415    -70.66290415]
# Mean squared error: 30878474.05
# Coefficient of determination: 0.79

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LassoCV
kf = KFold(n_splits=100, shuffle=True, random_state=0)
lasso_cv = LassoCV(cv=kf, max_iter=10000, random_state=0)
lasso_cv.fit(x, y)
print("Best alpha :", lasso_cv.alpha_)


Y_pred = lasso_cv.predict(x)

mse = mean_squared_error(y, Y_pred)
r2 = r2_score(y, Y_pred)


print('Mean squared error: %.2f' % mse)
print('Coefficient of determination: %.2f' % r2)
# Out:
# Best alpha : 10.410726425393213
# Mean squared error: 31018630.63
# Coefficient of determination: 0.79

# %%
from sklearn.svm import SVR
model = SVR(kernel='linear', C=1.0, epsilon=0.2)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("(MSE):", mse)
print("(R-squared):", r2)
# Out:
# (MSE): 97027731.18514387
# (R-squared): 0.33150151240627945
